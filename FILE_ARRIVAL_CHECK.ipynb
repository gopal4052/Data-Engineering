# %%
files = dbutils.fs.ls("/Volumes/my_local_data/raw_data/retail_sales_analytics_data")
print(files)
if len(files) == 0:
    dbutils.notebook.exit("NO_FILE")
else:
    dbutils.notebook.exit("FILE_PRESENT")
